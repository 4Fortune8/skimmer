# %%
# %pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
YoutubeProfiles = pd.read_csv('data\profiles\profiles2024-10.csv',index_col = None)
YoutubeProfiles.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Abdul\AppData\Local\Temp\ipykernel_38332\2577707381.py:1: SyntaxWarning: invalid escape sequence '\p'
#   YoutubeProfiles = pd.read_csv('data\profiles\profiles2024-10.csv',index_col = None)
#                      currentAccount  suscribers suscribersChange         view  \
# 0                    Well Off Media      484000            +1.68    206190000
# 1                          SypherPK     9760000            +1.14   4930000000
# 2                     Shiloh & Bros     8530000            +1.91   4360000000
# 3                    YouTube Movies      350000           -0.28%   2970000000
# 4  MSA previously My Story Animated    22500000            +1.35  10530000000
#
#   viewChange  earningsLow  earninghigh  engagment  uploadFrequency  avgLength  \
# 0       +2.2       4500.0      13500.0       4.24             4.50      20.39
# ...

# %%
YoutubeProfiles['suscribers'] = pd.to_numeric(YoutubeProfiles['suscribers'], errors='coerce')

YoutubeProfiles['suscribersChange'] = pd.to_numeric(YoutubeProfiles['suscribersChange'], errors='coerce')

YoutubeProfiles['suscribersChange'] = pd.to_numeric(YoutubeProfiles['suscribersChange'], errors='coerce')

YoutubeProfiles['viewChange'] = pd.to_numeric(YoutubeProfiles['viewChange'], errors='coerce')

SmallChannels = YoutubeProfiles[YoutubeProfiles['suscribers'] < 1000000]
MediumChannels = YoutubeProfiles[(YoutubeProfiles['suscribers'] > 500000) & (YoutubeProfiles['subs'] < 1000000)]
LargeChannels= YoutubeProfiles[(YoutubeProfiles['suscribers'] > 1000000) & (YoutubeProfiles['subs'] < 3000000)]
MassiveChannels = YoutubeProfiles[YoutubeProfiles['suscribers'] > 3000000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Abdul\miniconda3\envs\imggen\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Abdul\miniconda3\envs\imggen\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Abdul\miniconda3\envs\imggen\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'subs'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
SmallChannels = SmallChannels.sort_values('earninghigh', ascending=False)
MediumChannels = MediumChannels.sort_values('earninghigh', ascending=False)
LargeChannels= LargeChannels.sort_values('earninghigh', ascending=False)
MassiveChannels = MassiveChannels.sort_values('earninghigh', ascending=False)
SmallChannels.to_csv('data/Earsmallexport.csv')
MediumChannels.to_csv('data/Earmediumexport.csv')
LargeChannels.to_csv('data/Earlargeexport.csv')
MassiveChannels.to_csv('data/Earmassiveexport.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 SmallChannels = SmallChannels.sort_values('earninghigh', ascending=False)
# ----> 2 MediumChannels = MediumChannels.sort_values('earninghigh', ascending=False)
#       3 LargeChannels= LargeChannels.sort_values('earninghigh', ascending=False)
#       4 MassiveChannels = MassiveChannels.sort_values('earninghigh', ascending=False)
#
# NameError: name 'MediumChannels' is not defined

# %%
import pandas as pd
import numpy as np

YoutubeProfiles = pd.read_csv('data\\suscribersChangesSTinyexport.csv', index_col=0)
YoutubeProfiles.head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 YoutubeProfiles = pd.read_csv('data\\suscribersChangesSTinyexport.csv', index_col=0)
#       5 YoutubeProfiles.head(20)
#
# ...

# %%
import pandas as pd
import numpy as np

YoutubeProfiles = pd.read_csv('data\\newviewsSTinyexport.csv', index_col=0)
YoutubeProfiles.head(20)
# Out:
#                                 suscribers  suscribersChange      view  \
# currentAccount
# COUNTRY COLLECTION                   45700              8.81   1610000
# Brook Hoop                           10500            228.13   4030000
# Smdhn-YT                             25200           1418.07   2360000
# the white room                       12200            143.03   3370000
# Top Songs                            42500             80.08  12220000
# Healing Frequency for Soul           34000            125.17   3630000
# SWAG Lab - Motorcycle Crashes        12200             61.59   9380000
# QVC+ HSN+                            15400              7.69    871650
# Players Unlimited - Basketball       13600             48.80   7990000
# Mr. Bricks                           30800             41.94   6420000
# Animal Love                          17100             26.67  10810000
# Pink Moon                            53100             29.51   4400000
# ...

# %%
YoutubeProfiles = pd.read_csv('data\\suscribersChangesSTinyexport.csv', index_col=0)
YoutubeProfiles.head(20)
# Out:
#                                 suscribers  suscribersChange        view  \
# currentAccount
# Claudia Sheinbaum Pardo             661000             41.85   132300000
# Bryson DeChambeau                   743000             22.00    82580000
# MoreCaseOh                          793000             19.79   107190000
# SnakeThug - Brawl Stars             847000             17.97   541900000
# Will Survives                       669000             14.36    89490000
# Uzoth                              1390000             13.01   145200000
# Stephen A. Smith                    704000              9.49   135250000
# Gil's Arena                         674000              9.42   361780000
# Collins Key Top Videos              653000              9.38   211920000
# Angelazz Brookhaven                1020000              9.32   245660000
# Kill Tony                          1180000              9.26   246600000
# CashBlox                           1020000              9.21   439980000
# ...

# %%
YoutubeProfiles = pd.read_csv('data\\newviewsSTinyexport.csv', index_col=0)
YoutubeProfiles.head(20)
# Out:
#                                 suscribers  suscribersChange       view  \
# currentAccount
# Claudia Sheinbaum Pardo             661000             41.85  132300000
# MoreCaseOh                          793000             19.79  107190000
# Bryson DeChambeau                   743000             22.00   82580000
# SnakeThug - Brawl Stars             847000             17.97  541900000
# Uzoth                              1390000             13.01  145200000
# Will Survives                       669000             14.36   89490000
# Gil's Arena                         674000              9.42  361780000
# Stephen A. Smith                    704000              9.49  135250000
# The Ramsey Show                     700000              5.26  252900000
# Cam Wilder                         1370000              7.87  195980000
# The Times and The Sunday Times      598000              8.53  202100000
# FOX Weather                         674000              8.01  351390000
# ...

# %%
YoutubeProfiles = pd.read_csv('data\\earninghighSTinyexport.csv', index_col=0)
YoutubeProfiles.head(20)
# Out:
#                                       suscribers  suscribersChange       view  \
# currentAccount
# TooTool                                   260000             84.40  157740000
# Law&Crime Trials                          346000             17.29   93840000
# Kountry Wayne                             366000              4.87  256750000
# Big Bang Theory                           279000             15.77  315870000
# ToolTastic                                204000             18.60   93390000
# We Got Ice                                310000              9.93  250730000
# KSL News                                  302000              3.78  268830000
# Focus全球新聞 Focus Global News               369000              6.03  266399999
# Casey LaDelle                             295000              5.73  129139999
# Shortcat                                  366000              7.65  293650000
# 9NEWS                                     399000              1.79  362290000
# ...
